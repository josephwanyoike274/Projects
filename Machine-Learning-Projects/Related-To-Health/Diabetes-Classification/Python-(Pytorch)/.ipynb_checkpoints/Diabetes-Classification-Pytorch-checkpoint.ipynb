# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import random_split
import pandas as pd

# %%
# Define your custom dataset class

# %%
class CustomDataset(Dataset):
    def __ini__(self, features, labels):
        self.features = features
        self.labels = labels
        
    def __getitem__(self, index):
        x = self.features[index]
        y = self.labels[index]
        return x, y
    
    def __len__ (self):
        return len(self.features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_116\891180031.py in <module>
# ----> 1 class CustomDataset(Dataset):
#       2     def __ini__(self, features, labels):
#       3         self.features = features
#       4         self.labels = labels
#       5
#
# NameError: name 'Dataset' is not defined

# %%
# Define the logistic regression model

# %%
class LogisticRegression(nn.Module):
    def __init__(self, input_dim):
        super(LogisticRegression, self).__init__()
        self.linear = nn.Linear(input_dim, 1)
        self.sigmoid = nn.Sigmoid
        
    def forward(self, x):
        logits = self.linear(x)
        probablities = self.sigmoid(logits)
        return probablities

# %% [markdown]
# # Preparing our data

# %%
data = pd.read_csv("Diabetes-Classification.csv")

# %%
data
# Out:
#       PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0       1354778            0            171                      80
# 1       1147438            8             92                      93
# 2       1640031            7            115                      47
# 3       1883350            9            103                      78
# 4       1424119            1             85                      59
# ...         ...          ...            ...                     ...
# 9995    1469198            6             95                      85
# 9996    1432736            0             55                      51
# 9997    1410962            5             99                      59
# 9998    1958653            0            145                      67
# 9999    1332938           10            100                      54
#
#       TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  \
# 0                   34            23  43.509726          1.213191   21
# ...

# %%
features = data[["Pregnancies", "PlasmaGlucose", "DiastolicBloodPressure", "TricepsThickness", "SerumInsulin", "BMI", "DiabetesPedigree", "Age"]]

# %%
features
# Out:
#       Pregnancies  PlasmaGlucose  DiastolicBloodPressure  TricepsThickness  \
# 0               0            171                      80                34
# 1               8             92                      93                47
# 2               7            115                      47                52
# 3               9            103                      78                25
# 4               1             85                      59                27
# ...           ...            ...                     ...               ...
# 9995            6             95                      85                37
# 9996            0             55                      51                 7
# 9997            5             99                      59                47
# 9998            0            145                      67                30
# 9999           10            100                      54                34
#
#       SerumInsulin        BMI  DiabetesPedigree  Age
# ...

# %%
labels = data[["Diabetic"]]

# %%
labels
# Out:
#       Diabetic
# 0            0
# 1            0
# 2            0
# 3            1
# 4            0
# ...        ...
# 9995         0
# 9996         0
# 9997         1
# 9998         0
# 9999         0
#
# [10000 rows x 1 columns]

# %%
# Convert the features and labels to PyTorch tensors

# %%
features_tensor = torch.Tensor(features.values)#, dtype=torch.float32)
labels_tensor = torch.Tensor(labels.values)#, dtype=torch.float32)

# %%
dataset = CustomDataset(features, labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2560\19466312.py in <module>
# ----> 1 dataset = CustomDataset(features, labels)
#
# TypeError: CustomDataset() takes no arguments

# %%
# Print the shapes of the tensors

# %%
print("Features_shape:", features_tensors.shape)

# %%
print("labels_shape:", labels_tensors.shape)

# %%
#Create an instance of the logistic regression model and define the loss function and optimizer.

# %%
input_dim = data.shape[1]
model = LogisticRegression(input_dim)
cliterion = nn.BCELoss #Binary Cross Entropy Loss
optimizer = optim.SGD(model.parameters(), lr=0.01) #Stochastic Gradient Descent optimizer

# %%
#training the logistic regression model using the prepared data

# %%
num_epochs = 100
for epoch in range(num_epochs):
    #forward pass
    output = model(data)
    loss = criterion(output, train_labels)
    
    #backward and optimize
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    # Print the loss for every few epochs
    if (epoch+1) % 10 == 0:
        print(f" Epoch[{epoch+1} / {num_epochs}], loss:{loss.item():.4f}")
